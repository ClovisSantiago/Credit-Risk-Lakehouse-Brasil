# %% [markdown]
# ## Consultando os dados da dimensão de clientes

# %%
df_cliente =(
  spark.read.option("header", "True")
  .option("inferSchema", "True")
  .csv("/Volumes/dev_credit_risk/bronze/data_source/dim_cliente_raw.csv")
)
df_cliente.display()

# %% [markdown]
# ##Criando e escrevendo dados na tabela delta dim_cliente

# %%
path = "dev_credit_risk.bronze."
df_cliente.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable(path + "dim_cliente")
